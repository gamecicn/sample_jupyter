# %%
import tensorflow as tf
import pandas as pd
import sagemaker

# %%
# Change working driectory
# cd /home/ec2-user/SageMaker/TF_LSTM_Emotion

# %%
df = pd.read_csv('./data/ISEAR_clean.csv', sep=',')

# %%
df.head()
# Out:
#    emotion                                               text
# 0      joy  During the period of falling in love, each tim...
# 1     fear         When I was involved in a traffic accident.
# 2    anger  When I was driving home after  several days of...
# 3  sadness  When I lost the person who meant the most to me.
# 4  disgust  The time I knocked a deer down - the sight of ...

# %%
df.shape
# Out:
# (7668, 2)

# %% [markdown]
# ## Convert sentiment label to numeric category

# %%
labels = df.emotion.factorize()

# %%
labels_index = labels[1]
df['emotion'] = labels[0]
df.head(10)
# Out:
#    emotion                                               text
# 0        0  During the period of falling in love, each tim...
# 1        1         When I was involved in a traffic accident.
# 2        2  When I was driving home after  several days of...
# 3        3  When I lost the person who meant the most to me.
# 4        4  The time I knocked a deer down - the sight of ...
# 5        5                    When I did not speak the truth.
# 6        6  When I caused problems for somebody because he...
# 7        0  When I got a letter offering me the Summer job...
# 8        1  When I was going home alone one night in Paris...
# 9        2  When I was talking to HIM at a party for the f...

# %%
labels_index
# Out:
# Index(['joy', 'fear', 'anger', 'sadness', 'disgust', 'shame', 'guilt'], dtype='object')

# %%
## Split training data

# %%
from sklearn.model_selection import train_test_split

training_data, testing_data, y_train, y_test = train_test_split(df.text, df.emotion, test_size=0.2, random_state=123, shuffle=True)

print("training size {}".format(len(training_data)))
print("testing size {}".format(len(testing_data)))
# Out:
# training size 6134
# testing size 1534

# %%
traind_data = pd.DataFrame(data = {"text" : training_data, "emotion" : y_train})
test_data   = pd.DataFrame(data = {"text" : testing_data,  "emotion" : y_test})

training_data.fillna("", inplace = True)
test_data.fillna("", inplace = True)

# %%
traind_data.shape
# Out:
# (6134, 2)

# %%
test_data.shape
# Out:
# (1534, 2)

# %%
traind_data.to_csv('data/train.csv', index=False)
test_data.to_csv('data/test.csv', index=False)

# %%
sage_maker_session = sagemaker.Session()

prefix = 'tf-emotion-analysis'
training_input_path = sage_maker_session.upload_data('data/train.csv', key_prefix=prefix+'/training')

training_input_path
# Out:
# 's3://sagemaker-us-east-1-105372338271/tf-emotion-analysis/training/train.csv'

# %%
training_data = pd.read_csv(training_input_path, sep=',')
training_data.head(5)
# Out:
#                                                 text  emotion
# 0  I was angry about several drivers who showed a...        2
# 1  A woman picked her nose and spit right next to...        4
# 2  Bisshop Ter Schure intoduced himself on TV to ...        4
# 3  When an employer of my younger sister (17 yrs)...        4
# 4  During my first week in Graz I met a girl who ...        0

# %%
type(training_data.text.values[0])
# Out:
# str

# %%
# %%writefile train.py

import argparse
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Dense
from tensorflow.keras.layers import Embedding, Dropout
import pandas as pd

if __name__ == '__main__':
    
    parser = argparse.ArgumentParser()

    # hyperparameters sent by the client are passed as command-line arguments to the script.
    parser.add_argument('--epochs', type=int, default=10)
    parser.add_argument('--batch-size', type=int, default=100)
    parser.add_argument('--learning-rate', type=float, default=0.1)
    

    parser.add_argument('--gpu-count', type=int, default=os.environ['SM_NUM_GPUS'])

    # input data and model directories
    parser.add_argument('--model-dir', type=str, default=os.environ['SM_MODEL_DIR'])
    parser.add_argument('--train', type=str, default=os.environ['SM_CHANNEL_TRAIN'])
    #parser.add_argument('--test', type=str, default=os.environ['SM_CHANNEL_TEST'])

    args, _ = parser.parse_known_args()
    
    epochs     = args.epochs
    lr         = args.learning_rate
    batch_size = args.batch_size
    gpu_count  = args.gpu_count
    model_dir  = args.model_dir
    training_dir   = args.train
    
    training_data = pd.read_csv(training_dir+'/train.csv', sep=',')
    training_data.text.fillna("", inplace=True)
    
    tweet = training_data.text.values
    labels = training_data.emotion.values
    
    num_of_words = 1000
    token = Tokenizer(num_words=num_of_words)
    token.fit_on_texts(tweet)
    
    vocab_size = len(token.word_index) + 1 # 1 is added due to 0 index
    
    tweet_sequence = token.texts_to_sequences(tweet)
    
    max_len = 200
    padded_tweet_sequence = pad_sequences(tweet_sequence, maxlen=max_len)
    
    # Build the model
    embedding_vector_length = 32
    model = Sequential() 
    model.add(Embedding(vocab_size, embedding_vector_length, input_length=max_len) )
    model.add(Dropout(0.2))
    model.add(LSTM(20)) 
    model.add(Dropout(0.2))
    model.add(Dense(1, activation='sigmoid')) 
    model.compile(loss='binary_crossentropy',optimizer='adam', metrics=['accuracy']) 
    
    model.fit(padded_tweet_sequence,labels,validation_split=0.3, epochs=epochs, batch_size=batch_size, verbose=2)
    
    tf.saved_model.simple_save(
        tf.keras.backend.get_session(),
        os.path.join(model_dir, '1'),
        inputs={'inputs': model.input},
        outputs={t.name: t for t in model.outputs})
# Out:
# Overwriting train.py

# %%
tf_version = tf.__version__
tf_version
# Out:
# '2.0.3'

# %%
role = sagemaker.get_execution_role()

# %%
from sagemaker.tensorflow import TensorFlow

tf_estimator = TensorFlow(entry_point='train.py', 
                          role=role,
                          train_instance_count=2, 
                          train_instance_type='ml.c5.4xlarge',
                          script_mode=True,
                          hyperparameters={
                              'epochs': 10,
                              'batch-size': 64
                          }
                         )
# Out:
# No framework_version specified, defaulting to version 1.11. framework_version will be required in SageMaker Python SDK v2. This is not the latest supported version. If you would like to use version 2.2.0, please add framework_version=2.2.0 to your constructor.
# 2.1.0 is the latest version of tensorflow that supports Python 2. Newer versions of tensorflow will only be available for Python 3.Please set the argument "py_version='py3'" to use the Python 3 tensorflow image.

# %%
training_input_path
# Out:
# 's3://sagemaker-us-east-1-105372338271/tf-emotion-analysis/training/train.csv'

# %%
tf_estimator.fit({'train': training_input_path})
# Out:
# 'create_image_uri' will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 'create_image_uri' will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# 2020-10-24 11:42:58 Starting - Starting the training job...
# 2020-10-24 11:43:00 Starting - Launching requested ML instances.........
# 2020-10-24 11:44:32 Starting - Preparing the instances for training...
# 2020-10-24 11:45:18 Downloading - Downloading input data......
# 2020-10-24 11:46:17 Training - Training image download completed. Training in progress.2020-10-24 11:46:19,362 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2020-10-24 11:46:19,369 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2020-10-24 11:46:20,004 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2020-10-24 11:46:20,012 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2020-10-24 11:46:20,485 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2020-10-24 11:46:20,500 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2020-10-24 11:46:20,509 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "module_dir": "s3://sagemaker-us-east-1-105372338271/sagemaker-tensorflow-scriptmode-2020-10-24-11-42-57-730/source/sourcedir.tar.gz",
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     },
#     "resource_config": {
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "network_interface_name": "eth0",
#         "current_host": "algo-2"
#     },
#     "num_cpus": 16,
#     "log_level": 20,
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "input_config_dir": "/opt/ml/input/config",
#     "additional_framework_parameters": {},
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "model_dir": "/opt/ml/model",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "master_hostname": "algo-1",
#     "hyperparameters": {
#         "epochs": 10,
#         "batch-size": 64,
#         "model_dir": "s3://sagemaker-us-east-1-105372338271/sagemaker-tensorflow-scriptmode-2020-10-24-11-42-57-730/model"
#     },
#     "network_interface_name": "eth0",
#     "num_gpus": 0,
#     "input_dir": "/opt/ml/input",
#     "user_entry_point": "train.py",
#     "job_name": "sagemaker-tensorflow-scriptmode-2020-10-24-11-42-57-730",
#     "current_host": "algo-2",
#     "is_master": false,
#     "module_name": "train",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "RecordWrapperType": "None",
#             "S3DistributionType": "FullyReplicated"
#         }
#     },
#     "framework_module": "sagemaker_tensorflow_container.training:main"
# }
#
# Environment variables:
#
# SM_INPUT_DIR=/opt/ml/input
# SM_USER_ENTRY_POINT=train.py
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-2","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"batch-size":64,"epochs":10,"model_dir":"s3://sagemaker-us-east-1-105372338271/sagemaker-tensorflow-scriptmode-2020-10-24-11-42-57-730/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":false,"job_name":"sagemaker-tensorflow-scriptmode-2020-10-24-11-42-57-730","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-105372338271/sagemaker-tensorflow-scriptmode-2020-10-24-11-42-57-730/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":16,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-2","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_CHANNELS=["train"]
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_USER_ARGS=["--batch-size","64","--epochs","10","--model_dir","s3://sagemaker-us-east-1-105372338271/sagemaker-tensorflow-scriptmode-2020-10-24-11-42-57-730/model"]
# SM_NUM_GPUS=0
# SM_MODULE_NAME=train
# SM_MODULE_DIR=s3://sagemaker-us-east-1-105372338271/sagemaker-tensorflow-scriptmode-2020-10-24-11-42-57-730/source/sourcedir.tar.gz
# SM_HP_BATCH-SIZE=64
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=16
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_HPS={"batch-size":64,"epochs":10,"model_dir":"s3://sagemaker-us-east-1-105372338271/sagemaker-tensorflow-scriptmode-2020-10-24-11-42-57-730/model"}
# SM_HP_MODEL_DIR=s3://sagemaker-us-east-1-105372338271/sagemaker-tensorflow-scriptmode-2020-10-24-11-42-57-730/model
# SM_FRAMEWORK_PARAMS={}
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_CURRENT_HOST=algo-2
# SM_HOSTS=["algo-1","algo-2"]
# SM_HP_EPOCHS=10
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_RESOURCE_CONFIG={"current_host":"algo-2","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"}
# SM_LOG_LEVEL=20
# SM_MODEL_DIR=/opt/ml/model
#
# Invoking script with the following command:
#
# /usr/bin/python train.py --batch-size 64 --epochs 10 --model_dir s3://sagemaker-us-east-1-105372338271/sagemaker-tensorflow-scriptmode-2020-10-24-11-42-57-730/model
#
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/gradients_impl.py:108: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 4293 samples, validate on 1841 samples
# Epoch 1/10
#  - 23s - loss: -4.7904e+00 - acc: 0.1386 - val_loss: -1.1552e+01 - val_acc: 0.1581
# Epoch 2/10
#  - 21s - loss: -1.5831e+01 - acc: 0.1386 - val_loss: -1.8640e+01 - val_acc: 0.1581
# Epoch 3/10
#  - 21s - loss: -2.0343e+01 - acc: 0.1386 - val_loss: -2.2058e+01 - val_acc: 0.1581
# Epoch 4/10
# 2020-10-24 11:47:35,369 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2020-10-24 11:47:35,384 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2020-10-24 11:47:35,394 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "module_dir": "s3://sagemaker-us-east-1-105372338271/sagemaker-tensorflow-scriptmode-2020-10-24-11-42-57-730/source/sourcedir.tar.gz",
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     },
#     "resource_config": {
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "network_interface_name": "eth0",
#         "current_host": "algo-1"
#     },
#     "num_cpus": 16,
#     "log_level": 20,
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "input_config_dir": "/opt/ml/input/config",
#     "additional_framework_parameters": {},
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "model_dir": "/opt/ml/model",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "master_hostname": "algo-1",
#     "hyperparameters": {
#         "epochs": 10,
#         "batch-size": 64,
#         "model_dir": "s3://sagemaker-us-east-1-105372338271/sagemaker-tensorflow-scriptmode-2020-10-24-11-42-57-730/model"
#     },
#     "network_interface_name": "eth0",
#     "num_gpus": 0,
#     "input_dir": "/opt/ml/input",
#     "user_entry_point": "train.py",
#     "job_name": "sagemaker-tensorflow-scriptmode-2020-10-24-11-42-57-730",
#     "current_host": "algo-1",
#     "is_master": true,
#     "module_name": "train",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "RecordWrapperType": "None",
#             "S3DistributionType": "FullyReplicated"
#         }
#     },
#     "framework_module": "sagemaker_tensorflow_container.training:main"
# }
#
# Environment variables:
#
# SM_INPUT_DIR=/opt/ml/input
# SM_USER_ENTRY_POINT=train.py
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"batch-size":64,"epochs":10,"model_dir":"s3://sagemaker-us-east-1-105372338271/sagemaker-tensorflow-scriptmode-2020-10-24-11-42-57-730/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"sagemaker-tensorflow-scriptmode-2020-10-24-11-42-57-730","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-105372338271/sagemaker-tensorflow-scriptmode-2020-10-24-11-42-57-730/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":16,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_CHANNELS=["train"]
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_USER_ARGS=["--batch-size","64","--epochs","10","--model_dir","s3://sagemaker-us-east-1-105372338271/sagemaker-tensorflow-scriptmode-2020-10-24-11-42-57-730/model"]
# SM_NUM_GPUS=0
# SM_MODULE_NAME=train
# SM_MODULE_DIR=s3://sagemaker-us-east-1-105372338271/sagemaker-tensorflow-scriptmode-2020-10-24-11-42-57-730/source/sourcedir.tar.gz
# SM_HP_BATCH-SIZE=64
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=16
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_HPS={"batch-size":64,"epochs":10,"model_dir":"s3://sagemaker-us-east-1-105372338271/sagemaker-tensorflow-scriptmode-2020-10-24-11-42-57-730/model"}
# SM_HP_MODEL_DIR=s3://sagemaker-us-east-1-105372338271/sagemaker-tensorflow-scriptmode-2020-10-24-11-42-57-730/model
# SM_FRAMEWORK_PARAMS={}
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_CURRENT_HOST=algo-1
# SM_HOSTS=["algo-1","algo-2"]
# SM_HP_EPOCHS=10
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"}
# SM_LOG_LEVEL=20
# SM_MODEL_DIR=/opt/ml/model
#
# Invoking script with the following command:
#
# /usr/bin/python train.py --batch-size 64 --epochs 10 --model_dir s3://sagemaker-us-east-1-105372338271/sagemaker-tensorflow-scriptmode-2020-10-24-11-42-57-730/model
#
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/ops/gradients_impl.py:108: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 4293 samples, validate on 1841 samples
# Epoch 1/10
#  - 21s - loss: -2.3562e+01 - acc: 0.1386 - val_loss: -2.5210e+01 - val_acc: 0.1581
# Epoch 5/10
#  - 23s - loss: -3.5005e+00 - acc: 0.1395 - val_loss: -9.7782e+00 - val_acc: 0.1581
# Epoch 2/10
#  - 21s - loss: -2.6763e+01 - acc: 0.1386 - val_loss: -2.8124e+01 - val_acc: 0.1581
# Epoch 6/10
#  - 21s - loss: -1.4297e+01 - acc: 0.1386 - val_loss: -1.7596e+01 - val_acc: 0.1581
# Epoch 3/10
#  - 21s - loss: -2.9176e+01 - acc: 0.1386 - val_loss: -3.1686e+01 - val_acc: 0.1581
# Epoch 7/10
#  - 21s - loss: -1.9422e+01 - acc: 0.1386 - val_loss: -2.1443e+01 - val_acc: 0.1581
# Epoch 4/10
#  - 21s - loss: -3.0359e+01 - acc: 0.1386 - val_loss: -3.1686e+01 - val_acc: 0.1581
# Epoch 8/10
#  - 21s - loss: -2.3029e+01 - acc: 0.1386 - val_loss: -2.4736e+01 - val_acc: 0.1581
# Epoch 5/10
#  - 21s - loss: -3.0902e+01 - acc: 0.1386 - val_loss: -3.1686e+01 - val_acc: 0.1581
# Epoch 9/10
#  - 21s - loss: -2.6178e+01 - acc: 0.1386 - val_loss: -2.7818e+01 - val_acc: 0.1581
# Epoch 6/10
#  - 21s - loss: -3.1175e+01 - acc: 0.1386 - val_loss: -3.1686e+01 - val_acc: 0.1581
# Epoch 10/10
#  - 21s - loss: -2.8813e+01 - acc: 0.1386 - val_loss: -3.0308e+01 - val_acc: 0.1581
# Epoch 7/10
#  - 21s - loss: -3.1294e+01 - acc: 0.1386 - val_loss: -3.1686e+01 - val_acc: 0.1581
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/saved_model/simple_save.py:85: calling add_meta_graph_and_variables (from tensorflow.python.saved_model.builder_impl) with legacy_init_op is deprecated and will be removed in a future version.
# Instructions for updating:
# Pass your op to the equivalent parameter main_op instead.
# 2020-10-24 11:49:55,329 sagemaker-containers INFO     Reporting training SUCCESS
#  - 21s - loss: -3.0191e+01 - acc: 0.1386 - val_loss: -3.1686e+01 - val_acc: 0.1581
# Epoch 8/10
#  - 21s - loss: -3.0833e+01 - acc: 0.1386 - val_loss: -3.1686e+01 - val_acc: 0.1581
# Epoch 9/10
#  - 21s - loss: -3.1172e+01 - acc: 0.1386 - val_loss: -3.1686e+01 - val_acc: 0.1581
# Epoch 10/10
#  - 21s - loss: -3.1283e+01 - acc: 0.1386 - val_loss: -3.1686e+01 - val_acc: 0.1581
# WARNING:tensorflow:From /usr/local/lib/python2.7/dist-packages/tensorflow/python/saved_model/simple_save.py:85: calling add_meta_graph_and_variables (from tensorflow.python.saved_model.builder_impl) with legacy_init_op is deprecated and will be removed in a future version.
# Instructions for updating:
# Pass your op to the equivalent parameter main_op instead.
# 2020-10-24 11:51:09,486 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2020-10-24 11:51:29 Uploading - Uploading generated training model
# 2020-10-24 11:51:29 Completed - Training job completed
# Training seconds: 742
# Billable seconds: 742

# %%
import time

endpoint_name = 'tf-emotion-analysis'+time.strftime("%Y-%m-%d-%H-%M-%S", time.gmtime())
end_point = tf_estimator.deploy(initial_instance_count=1, instance_type='ml.m5.4xlarge', endpoint_name=endpoint_name)
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# 'create_image_uri' will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# -----------!

# %%
print(end_point.endpoint)
# Out:
# tf-emotion-analysis2020-10-24-11-52-15

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

def preprocess_texts(text):
    
    num_of_words = 100
    token = Tokenizer(num_words=num_of_words)
    
    training_data.fillna("", inplace=True)
    token.fit_on_texts(training_data.text.values)
    
    tweet_sequence = token.texts_to_sequences(text)
    
    max_len = 200
    padded_tweet_sequence = pad_sequences(tweet_sequence, maxlen=max_len)
    
    return padded_tweet_sequence

# %%
test_data.fillna("", inplace=True)
test_texts = preprocess_texts(test_data.text.values)

# %%
labels_index
# Out:
# Index(['joy', 'fear', 'anger', 'sadness', 'disgust', 'shame', 'guilt'], dtype='object')

# %%
import numpy as np

for i, tweet in enumerate(test_texts):
 
    print(test_data.text.values[i])
    prediction = end_point.predict(tweet)['predictions']
    prediction = np.array(prediction).round().item()
    print('Actual sentiment: {} ----- Predicted sentiment  {} \n'.format(test_data.emotion.values[i], labels_index[int(prediction)]))
# Out:
# I was walking home from a place on southside and I live on á Northside and I was followed. I headed my most direct route.
# Actual sentiment: 1 ----- Predicted sentiment  fear
#
# Somebody who knows me very well discovered that I had told him a á lie.
# Actual sentiment: 5 ----- Predicted sentiment  fear
#
# During the Chinese lessons a student often showed off. Moreover á he misbehaved and dressed very badly.  So disgusting !
# Actual sentiment: 4 ----- Predicted sentiment  fear
#
# I am a kindergarten teacher and I am thoroughly weary of my job.  á After having taken the university entrance exam I suffered from á anxiety for weeks as I did not want to carry on with my work - studies á were the only alternative.
# Actual sentiment: 1 ----- Predicted sentiment  fear
#
# I went to the school library and asked for a book, but the á librarian told me that there wasn't such. However when an other á colleague asked for it she gave it to him.
# Actual sentiment: 2 ----- Predicted sentiment  fear
#
# My first girlfriend. I had the feeling that she was going out á with me only because of my defect.
# Actual sentiment: 5 ----- Predicted sentiment  fear
#
# I was supposed to be studying for my math midterm a few days ago, á however, I fooled around with my roommate, and didn't start á studying until 12:00 am. I was disgusted with myself.
# Actual sentiment: 4 ----- Predicted sentiment  fear
#
#

# Actual sentiment: 3 ----- Predicted sentiment  fear
#
# My elder sister whom I love very much was leaving for the          á West Indies for two years and I was staying behind.
# Actual sentiment: 3 ----- Predicted sentiment  fear
#
# A rainy day, I was cycling downhill and a car door suddenly á opened and while trying to avoid it the back wheels of my bike á got caught in the tram tracks.  I somersaulted but had no á injuries.
# Actual sentiment: 1 ----- Predicted sentiment  fear
#
# After intercourse.
# Actual sentiment: 0 ----- Predicted sentiment  fear
#
# When I went to see the dead body of my uncle.  This was a very á dramatic expreience as it was the first time that I entered a á mortuary.
# Actual sentiment: 3 ----- Predicted sentiment  fear
#
# When I as a child of 9 or 10 I was playing doctor with the á neighbours boys their mother caught us.
# Actual sentiment: 5 ----- Predicted sentiment  fear
#
# Made a wonderful driend who understands me.
# Actual sentiment: 0 ----- Predicted sentiment  fear
#
# Failing an examn.
# Actual sentiment: 5 ----- Predicted sentiment  fear
#
# The emotion came when a certain boy opened my locker without my á knowledge.
# Actual sentiment: 2 ----- Predicted sentiment  fear
#
# In the last day of carnaval I met a boy and began to flirt with á him. I was in love with him. When he introduced me to his friends á I died of shame because I was with them before, I met my á boyfriend in carnaval.
# Actual sentiment: 5 ----- Predicted sentiment  fear
#
# I insulted two of my friends because I thought that had been á gossiping about me right under my nose, however I later found out á that they were not doing so.
# Actual sentiment: 5 ----- Predicted sentiment  fear
#
# Unofficially I was informed about my results of the final á examination of the secondary school. A teacher wrote them up for á me. When I went outside, I started crying with joy.
# Actual sentiment: 0 ----- Predicted sentiment  fear
#
# When I was trying for a girl who I really liked and cared for and á thought she felt the same way too. But she didn't like the idea á and just wanted to stay friends.
# Actual sentiment: 3 ----- Predicted sentiment  fear
#
# In March I was busy studying during the night I could only sleep á two or three hours only for fear that I would be weeded and sent á back.
# Actual sentiment: 1 ----- Predicted sentiment  fear
#
# Sitting on the bus seats supposed for disabled people, children á and old people (by mistake)
# Actual sentiment: 5 ----- Predicted sentiment  fear
#
# When my sister lost my favourite jumper at a party and failed to á tell me for several days after it happened.
# Actual sentiment: 2 ----- Predicted sentiment  fear
#
# My uncle died - I felt sad at the funeral.
# Actual sentiment: 3 ----- Predicted sentiment  fear
#
# When I found out I got accepted to Berkeley.
# Actual sentiment: 0 ----- Predicted sentiment  fear
#
# When I do not put in the needed amount of hours of work or study á for the day, I feel guilty and try to make up for the lost á time.
# Actual sentiment: 6 ----- Predicted sentiment  fear
#
# Once a female classmate told me that the clothes I wore seemed to á be a child's clothes.  On hearing this I felt a little ashamed and á I criticized her clothes though there was nothing wrong with á them.
# Actual sentiment: 5 ----- Predicted sentiment  fear
#
# We had to take our cat to the vet for mercy killing (an á injection).
# Actual sentiment: 3 ----- Predicted sentiment  fear
#
# When my brother ran away from home and I thought it was because á of my continously scolding him.
# Actual sentiment: 6 ----- Predicted sentiment  fear
#
# I felt alone among a large number of people.  I was sad to see á that nobody cared about what was happening to me.
# Actual sentiment: 3 ----- Predicted sentiment  fear
#
# Saw something stupid and ignorant happening in the countryside.
# Actual sentiment: 5 ----- Predicted sentiment  fear
#
# Exchange of points of view with my sister on a family matter.
# Actual sentiment: 2 ----- Predicted sentiment  fear
#
# When I was young I was playing football near my parent's house á and while playing I fell on the ground. At first I thought I was á not seen by anybody, but when my mother laughed I felt very á ashamed.
# Actual sentiment: 5 ----- Predicted sentiment  fear
#
# The same as in \shame\.
# Actual sentiment: 6 ----- Predicted sentiment  fear
#
# When I betrayed my former girlfriend.
# Actual sentiment: 6 ----- Predicted sentiment  fear
#
# Forgot to turn up on prescribed day for jury service.
# Actual sentiment: 6 ----- Predicted sentiment  fear
#
# When I made a mistake at work and when questioned about it á pretended I had nothing to do with the problem.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-150-ac42820248c1> in <module>
#       4
#       5     print(test_data.text.values[i])
# ----> 6     prediction = end_point.predict(tweet)['predictions']
#       7     prediction = np.array(prediction).round().item()
#       8     print('Actual sentiment: {} ----- Predicted sentiment  {} \n'.format(test_data.emotion.values[i], labels_index[int(prediction)]))
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/sagemaker/tensorflow/serving.py in predict(self, data, initial_args)
#     118                 args["CustomAttributes"] = self._model_attributes
#     119
# --> 120         return super(Predictor, self).predict(data, args)
#     121
#     122
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/sagemaker/predictor.py in predict(self, data, initial_args, target_model, target_variant)
#     111
#     112         request_args = self._create_request_args(data, initial_args, target_model, target_variant)
# --> 113         response = self.sagemaker_session.sagemaker_runtime_client.invoke_endpoint(**request_args)
#     114         return self._handle_response(response)
#     115
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     355                     "%s() only accepts keyword arguments." % py_operation_name)
#     356             # The "self" in this scope is referring to the BaseClient.
# --> 357             return self._make_api_call(operation_name, kwargs)
#     358
#     359         _api_call.__name__ = str(py_operation_name)
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     661         else:
#     662             http, parsed_response = self._make_request(
# --> 663                 operation_model, request_dict, request_context)
#     664
#     665         self.meta.events.emit(
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/botocore/client.py in _make_request(self, operation_model, request_dict, request_context)
#     680     def _make_request(self, operation_model, request_dict, request_context):
#     681         try:
# --> 682             return self._endpoint.make_request(operation_model, request_dict)
#     683         except Exception as e:
#     684             self.meta.events.emit(
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/botocore/endpoint.py in make_request(self, operation_model, request_dict)
#     100         logger.debug("Making request for %s with params: %s",
#     101                      operation_model, request_dict)
# --> 102         return self._send_request(request_dict, operation_model)
#     103
#     104     def create_request(self, params, operation_model=None):
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/botocore/endpoint.py in _send_request(self, request_dict, operation_model)
#     133         context = request_dict['context']
#     134         success_response, exception = self._get_response(
# --> 135             request, operation_model, context)
#     136         while self._needs_retry(attempts, operation_model, request_dict,
#     137                                 success_response, exception):
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/botocore/endpoint.py in _get_response(self, request, operation_model, context)
#     165         # If no exception occurs then exception is None.
#     166         success_response, exception = self._do_get_response(
# --> 167             request, operation_model)
#     168         kwargs_to_emit = {
#     169             'response_dict': None,
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/botocore/endpoint.py in _do_get_response(self, request, operation_model)
#     198             http_response = first_non_none_response(responses)
#     199             if http_response is None:
# --> 200                 http_response = self._send(request)
#     201         except HTTPClientError as e:
#     202             return (None, e)
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/botocore/endpoint.py in _send(self, request)
#     267
#     268     def _send(self, request):
# --> 269         return self.http_session.send(request)
#     270
#     271
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/botocore/httpsession.py in send(self, request)
#     261                 preload_content=False,
#     262                 decode_content=False,
# --> 263                 chunked=self._chunked(request.headers),
#     264             )
#     265
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     675                 body=body,
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#     679
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/http/client.py in getresponse(self)
#    1352         try:
#    1353             try:
# -> 1354                 response.begin()
#    1355             except ConnectionError:
#    1356                 self.close()
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1010                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#    1014             return socket.recv_into(self, buffer, nbytes, flags)
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/ssl.py in read(self, len, buffer)
#     872             raise ValueError("Read on closed or unwrapped SSL socket.")
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#     876             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# ~/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:
